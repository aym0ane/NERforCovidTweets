# %%
import pandas as pd
import tweepy
import configparser

# %%
# read configs
config = configparser.ConfigParser()
config.read('config.ini')
# Out:
# ['config.ini']

# %%
api_key = config['twitter']['api_key']
api_key_secret = config['twitter']['api_key_secret']

access_token = config['twitter']['access_token']
access_token_secret = config['twitter']['access_token_secret']

# %%
# authentication
auth = tweepy.OAuthHandler(api_key, api_key_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)

# %%
keywords =  ['covid'  , 'Remote', 'distance Learning'  ]
limit=500

tweets = tweepy.Cursor(api.search_tweets, q=keywords, count=500, tweet_mode='extended').items(limit)

columns = ['Tweet']
data = []

for tweet in tweets:
    data.append([ tweet.full_text])

df = pd.DataFrame(data, columns=columns)

# %%
df
# Out:
#                                                 Tweet
# 0   RT @VTVcanal8: #JornadaDeVacunación💉| ¡Adulto ...
# 1   RT @Helenasth: Globonews: alimentação fica 12%...
# 2   RT @BryanDeanWright: If you've been vaccinated...
# 3   @ChrisCostCFA @AyeshaTariq As a former employe...
# 4   Procura? A caça recomeçou.  Deus tenha miseric...
# 5   @globovision Ya la gente no les cree no hay ni...
# 6   RT @DanaMetcalfe5: Dr Derek Knauss tested 1500...
# 7   RT @GassmanGassmann: Ps Mi sono espresso male:...
# 8   RT @EricTopol: The tonsils and adenoids of chi...
# 9   @barbarab1974 Secondo me dovrebbe essere per s...
# 10  RT @Game8910: Current state of #holoEN\n\nMori...
# 11  RT @stephensemler: The FY2023 omnibus bill has...
# 12  @Thoracicus As a refugee from NSW... Qld had n...
# 13  RT @ricchaarr: ils savaient que le vaccin covi...
# 14  RT @elizavetaka: @KHoulgate They got ppl to th...
# 15  RT @julia_doubleday: Just saw an anecdote wher...
# 16  RT @MarionBerndt: "Lockdown-Poetry"-a poetic d...
# 17  RT @OuestFrance: Les Etats-Unis prêts à fourni...
# 18  @jonathanstea @PeterHotez @CaulfieldTim @dorit...
# 19  RT @DrJBhattacharya: "1)    Was Fauci involved...
# 20  RT @vijay27anand: China Covid Crisis has start...
# 21  Este miércoles 21 de diciembre ponte el refuer...
# 22  COVID-19 pushed Alaska’s death rate higher and...
# 23  RT @Strandjunker: 2 died of Ebola: They said O...
# 24  @DrHueyLi @SocialFuzzer @JessicaLexicus It’s a...
# 25  RT @EpochTimes: #Pfizer’s COVID-19 vaccine is ...
# 26  —Jungkook on his lyrics from ‘Still With You’\...
# 27  RT @PeterSweden7: Retweet if you agree that th...
# 28  RT @samanthamarika1: “Increased heart failure ...
# 29  @qldpeeplprotest They may of felt guilty about...
# 30  Wicked to think about how dirty the world was ...
# 31  RT @VTVcanal8: #PREVENCIÓN😷| Combate a la COVI...
# 32  @ReflectingMan Dang...that 3 years with zero c...
# 33  @DrEliDavid Yeah, zero evidence of COVID being...
# 34  @lecwah1 @wheresourLOGIC Covid for my wife and...
# 35  RT @LFProduct: We weren't all scared -\nIt was...
# 36  RT @DrEliDavid: Breaking: Israel 🇮🇱 Ministry o...
# 37  Things we’d love to know, but probably never w...
# 38  https://t.co/KjyqTOP3pz Lleig ho és (encara mé...
# 39  RT @tcp_dr: DESPATCHES FROM THE PHONEY COVID T...
# 40  Los de neumo realmente dijeron -nos vale verga...
# 41  RT @f_philippot: Incroyable enquête de l’agenc...
# 42  RT @julia_doubleday: Just saw an anecdote wher...
# 43  Öyle bir öksürük kriziyle boğuşuyorum ki; uyuy...
# 44  RT @DavidCOJ102: @AdHabb It looks like during ...
# 45  RT @DrEliDavid: @elonmusk The whole world is w...
# 46  RT @n000_132: I'm curious to hear everyone's r...
# 47  RT @blckbxnews: Een onderzoek van de Amerikaan...
# 48  RT @allaboutwembley: @tatereeves You’re a mise...
# 49  @mattjcan Amazing this was published \n\nhttps...

# %%
df.to_csv('DATA/DataScraped.csv' , index=False  )

# %% [markdown]
# # Done

# %% [markdown]
# ### By : MAANE Aymane
